# %% [markdown]
# # Project: Writing a Data Scientists Blog Post
#
# In this notebook I will be using sklearn and other ML learning libraries to analyse survey results.
#
# # 1. Importing the data

# %%
import pandas as pd
import os
import glob
from collections import Counter
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress all warnings
warnings.filterwarnings('ignore')

# %%
def load_year_from_csv(year):
    # defining the directory
    directory_path = os.path.join('..', 'data', 'stack-overflow-developer-survey-' + year)

    # Use glob to find all CSV files in the directory
    csv_files = glob.glob(os.path.join(directory_path, '*.csv'))

    try:
        df = pd.read_csv(csv_files[0], sep=',', encoding='ISO-8859-1')
    except UnicodeDecodeError as e:
        print(f"UnicodeDecodeError: {e}")

    return df

# creating a list of all the years we want to analise
years = ['2011',
        '2012',
        '2013',
        '2014',
        '2015',
        '2016',
        '2017',
        '2018',
        '2019',
        '2020',
        '2021',
        '2022',
        '2023',
        '2024']

data = []

for year in years:
    print('loading data for: ', year)
    data.append(load_year_from_csv(year));
# Out:
# loading data for:  2011
# loading data for:  2012
# loading data for:  2013
# loading data for:  2014
# loading data for:  2015
# loading data for:  2016
# loading data for:  2017
# loading data for:  2018
# loading data for:  2019
# loading data for:  2020
# loading data for:  2021
# loading data for:  2022
# loading data for:  2023
# loading data for:  2024

# %%
# Verify that both lists have the same length
assert len(years) == len(data), "The lists must have the same length"

# Pair each string with its corresponding DataFrame
paired_list = zip(years, data)

# Convert the paired list to a dictionary
data_dict = dict(paired_list)

# %% [markdown]
# # 2. Identify Common Survey questions
#
# In order to get an overview of the consistency of the survey over the years, we want to identify common questions and similarities over the years.

# %%
# Extract column names
column_names = {year: set(data.columns) for year, data in data_dict.items()}

# %%
# Find columns common to all DataFrames
common_columns = set.intersection(*column_names.values())

# %%
# Define the years for which you want to extract column names
selected_years = years[:]

# Extract column names for the selected years
all_columns_selected_years = []
for year in selected_years:
    if year in data_dict:
        all_columns_selected_years.extend(data_dict[year].columns)

# # Remove duplicates by converting the list to a set and back to a list
# all_columns_selected_years = list(set(all_columns_selected_years))

# Count the frequency of each column name
column_counter_selected_years = Counter(all_columns_selected_years)

# Print the column counts for verification
print(column_counter_selected_years)
# Out:
# Counter({'Country': 8, 'Employment': 7, 'DevType': 7, 'Age': 7, 'Currency': 6, 'Gender': 6, 'MainBranch': 6, 'EdLevel': 6, 'OrgSize': 6, 'YearsCode': 6, 'YearsCodePro': 6, 'CompTotal': 6, 'SOVisitFreq': 6, 'SOAccount': 6, 'SOPartFreq': 6, 'SOComm': 6, 'SurveyLength': 6, 'SurveyEase': 6, 'Unnamed: 16': 5, 'Unnamed: 17': 5, 'Unnamed: 18': 5, 'Unnamed: 23': 5, 'Unnamed: 24': 5, 'Unnamed: 25': 5, 'Unnamed: 27': 5, 'Unnamed: 28': 5, 'Unnamed: 31': 5, 'Unnamed: 32': 5, 'Unnamed: 33': 5, 'Unnamed: 35': 5, 'Unnamed: 36': 5, 'Unnamed: 47': 5, 'Unnamed: 48': 5, 'Unnamed: 50': 5, 'Unnamed: 52': 5, 'Unnamed: 53': 5, 'Unnamed: 57': 5, 'Unnamed: 58': 5, 'Unnamed: 59': 5, 'Unnamed: 60': 5, 'Unnamed: 61': 5, 'Unnamed: 62': 5, 'NEWSOSites': 5, 'Which US State or Territory do you live in?': 4, 'How old are you?': 4, 'How many years of IT/Programming experience do you have?': 4, 'Which of the following best describes your occupation?': 4, 'Unnamed: 10': 4, 'Unnamed: 11': 4, 'Unnamed: 12': 4, 'Unnamed: 13': 4, 'Unnamed: 14': 4, 'What types of purchases are you involved in?': 4, 'Unnamed: 19': 4, 'Unnamed: 22': 4, 'Unnamed: 26': 4, 'Unnamed: 37': 4, 'Unnamed: 38': 4, 'Unnamed: 39': 4, 'Unnamed: 40': 4, 'Including bonus, what is your annual compensation in USD?': 4, 'Which technology products do you own? (You can choose more than one)': 4, 'Unnamed: 49': 4, 'Unnamed: 51': 4, 'Unnamed: 54': 4, 'Unnamed: 55': 4, 'Unnamed: 56': 4, 'Unnamed: 15': 4, 'Unnamed: 30': 4, 'Unnamed: 43': 4, 'Unnamed: 45': 4, 'Unnamed: 46': 4, 'Unnamed: 63': 4, 'Unnamed: 66': 4, 'Unnamed: 69': 4, 'Unnamed: 74': 4, 'Respondent': 4, 'CompFreq': 4, 'Trans': 4, 'Sexuality': 4, 'Ethnicity': 4, 'ResponseId': 4, 'LearnCode': 4, 'LanguageHaveWorkedWith': 4, 'LanguageWantToWorkWith': 4, 'DatabaseHaveWorkedWith': 4, 'DatabaseWantToWorkWith': 4, 'PlatformHaveWorkedWith': 4, 'PlatformWantToWorkWith': 4, 'WebframeHaveWorkedWith': 4, 'WebframeWantToWorkWith': 4, 'MiscTechHaveWorkedWith': 4, 'MiscTechWantToWorkWith': 4, 'ToolsTechHaveWorkedWith': 4, 'ToolsTechWantToWorkWith': 4, 'NEWCollabToolsHaveWorkedWith': 4, 'NEWCollabToolsWantToWorkWith': 4, 'ConvertedCompYearly': 4, 'What Country or Region do you live in?': 3, 'Unnamed: 9': 3, 'Unnamed: 20': 3, 'Unnamed: 34': 3, 'Unnamed: 41': 3, 'How would you best describe the industry you currently work in?': 3, 'What is your involvement in purchasing products or services for the company you work for? (You can choose more than one)': 3, 'Unnamed: 29': 3, 'Which desktop operating system do you use the most?': 3, "Please rate the advertising you've seen on Stack Overflow": 3, 'Unnamed: 67': 3, 'Unnamed: 68': 3, 'Unnamed: 70': 3, 'What advertisers do you remember seeing on Stack Overflow?': 3, 'What is your current Stack Overflow reputation?': 3, 'Unnamed: 21': 3, 'Unnamed: 44': 3, 'Unnamed: 64': 3, 'Unnamed: 65': 3, 'Unnamed: 71': 3, 'Unnamed: 72': 3, 'Unnamed: 73': 3, 'Unnamed: 75': 3, 'Unnamed: 76': 3, 'Unnamed: 77': 3, 'Unnamed: 78': 3, 'Unnamed: 79': 3, 'Unnamed: 80': 3, 'Unnamed: 84': 3, 'Unnamed: 88': 3, 'Unnamed: 89': 3, 'Unnamed: 90': 3, 'Unnamed: 91': 3, 'Unnamed: 93': 3, 'Unnamed: 95': 3, 'Unnamed: 96': 3, 'Unnamed: 97': 3, 'Unnamed: 103': 3, 'Unnamed: 104': 3, 'Unnamed: 105': 3, 'Unnamed: 106': 3, 'Unnamed: 107': 3, 'Unnamed: 108': 3, 'Unnamed: 117': 3, 'Unnamed: 118': 3, 'UndergradMajor': 3, 'CurrencySymbol': 3, 'LanguageWorkedWith': 3, 'LanguageDesireNextYear': 3, 'DatabaseWorkedWith': 3, 'DatabaseDesireNextYear': 3, 'PlatformWorkedWith': 3, 'PlatformDesireNextYear': 3, 'Age1stCode': 3, 'JobSat': 3, 'OpSys': 3, 'RemoteWork': 3, 'CodingActivities': 3, 'LearnCodeOnline': 3, 'PurchaseInfluence': 3, 'BuyNewTool': 3, 'OpSysProfessional use': 3, 'OpSysPersonal use': 3, 'OfficeStackAsyncHaveWorkedWith': 3, 'OfficeStackAsyncWantToWorkWith': 3, 'OfficeStackSyncHaveWorkedWith': 3, 'OfficeStackSyncWantToWorkWith': 3, 'TBranch': 3, 'ICorPM': 3, 'WorkExp': 3, 'Knowledge_1': 3, 'Knowledge_2': 3, 'Knowledge_3': 3, 'Knowledge_4': 3, 'Knowledge_5': 3, ' ...

# %%
plt.barh(column_counter_selected_years.keys(), column_counter_selected_years.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_33388\4132559082.py in <module>
# ----> 1 plt.barh(column_counter_selected_years.keys(), column_counter_selected_years.values())
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\pyplot.py in barh(y, width, height, left, align, data, **kwargs)
#    2781     **kwargs,
#    2782 ) -> BarContainer:
# -> 2783     return gca().barh(
#    2784         y,
#    2785         width,
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, data, **kwargs)
#    2699         """
#    2700         kwargs.setdefault('orientation', 'horizontal')
# -> 2701         patches = self.bar(x=left, height=height, width=width, bottom=y,
#    2702                            align=align, data=data, **kwargs)
#    2703         return patches
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1463     def inner(ax, *args, data=None, **kwargs):
#    1464         if data is None:
# -> 1465             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1466
#    1467         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2439             # However, it is also possible for x=0 for the default and width
#    2440             # to contain unit information.  This will prioritize the units of x.
# -> 2441             self._process_unit_info(
#    2442                 [("x", x), ("x", width), ("y", y)], kwargs, convert=False)
#    2443             if log:
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, datasets, kwargs, convert)
#    2553             # Update from data if axis is already set but no unit is set yet.
#    2554             if axis is not None and data is not None and not axis.have_units():
# -> 2555                 axis.update_units(data)
#    2556         for axis_name, axis in axis_map.items():
#    2557             # Return if no axis is set.
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1710         neednew = self.converter != converter
#    1711         self.converter = converter
# -> 1712         default = self.converter.default_units(data, self)
#    1713         if default is not None and self.units is None:
#    1714             self.set_units(default)
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     103         # the conversion call stack is default_units -> axis_info -> convert
#     104         if axis.units is None:
# --> 105             axis.set_units(UnitData(data))
#     106         else:
#     107             axis.units.update(data)
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# c:\Users\P335437\AppData\Local\anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     212         # check if convertible to number:
#     213         convertible = True
# --> 214         for val in OrderedDict.fromkeys(data):
#     215             # OrderedDict just iterates over unique values in data.
#     216             _api.check_isinstance((str, bytes), value=val)
#
# TypeError: unhashable type: 'dict_keys'

# %%
sns.histplot(column_counter_selected_years)
# Out:
# <Axes: ylabel='Count'>

# %%
all_columns_selected_years.count('Country')
# Out:
# 8
